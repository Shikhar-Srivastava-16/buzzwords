# %%
from transformers import LlamaTokenizer, LlamaForCausalLM

# Load the model and tokenizer (replace 'llama-2' with the correct model ID)
model_name = "meta-llama/Llama-2-7b-hf"  # Example model, adjust as needed
tokenizer = LlamaTokenizer.from_pretrained(model_name)
model = LlamaForCausalLM.from_pretrained(model_name)

# Sample prompt
prompt = "What is the capital of France?"

# Tokenize the input
inputs = tokenizer(prompt, return_tensors="pt")

# Generate output
outputs = model.generate(**inputs, max_length=50)

# Decode the generated output
answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(answer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/utils/import_utils.py:1863, in _LazyModule._get_module(self, module_name)
#    1862 try:
# -> 1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
#
# File /usr/lib64/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/models/llama/modeling_llama.py:39
#      38 from ...modeling_rope_utils import ROPE_INIT_FUNCTIONS
# ---> 39 from ...modeling_utils import ALL_ATTENTION_FUNCTIONS, PreTrainedModel
#      40 from ...processing_utils import Unpack
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/modeling_utils.py:53
#      52 from .integrations.sdpa_attention import sdpa_attention_forward
# ---> 53 from .loss.loss_utils import LOSS_MAPPING
#      54 from .pytorch_utils import (  # noqa: F401
#      55     Conv1D,
#      56     apply_chunking_to_forward,
#    (...)
#      62     translate_to_torch_parallel_style,
#      63 )
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/loss/loss_utils.py:19
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/loss/loss_deformable_detr.py:4
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/image_transforms.py:22
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/image_utils.py:65
#      64 if is_torchvision_available():
# ---> 65     from torchvision import io as torchvision_io
#      66     from torchvision.transforms import InterpolationMode
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/torchvision/__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/torchvision/_meta_registrations.py:26
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/torchvision/_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 10
#       1 # import transformers as tr
#       2
#       3
#    (...)
#       7 # qa_model(question = question, context = context)
#       8 ## {'answer': 'İstanbul', 'end': 39, 'score': 0.953, 'start': 31}
# ---> 10 from transformers import LlamaTokenizer, LlamaForCausalLM
#      12 # Load the model and tokenizer (replace 'llama-2' with the correct model ID)
#      13 model_name = "meta-llama/Llama-2-7b-hf"  # Example model, adjust as needed
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/utils/import_utils.py:1852, in _LazyModule.__getattr__(self, name)
#    1850 elif name in self._class_to_module.keys():
#    1851     module = self._get_module(self._class_to_module[name])
# -> 1852     value = getattr(module, name)
#    1853 elif name in self._modules:
#    1854     value = self._get_module(name)
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/utils/import_utils.py:1851, in _LazyModule.__getattr__(self, name)
#    1849     value = Placeholder
#    1850 elif name in self._class_to_module.keys():
# -> 1851     module = self._get_module(self._class_to_module[name])
#    1852     value = getattr(module, name)
#    1853 elif name in self._modules:
#
# File /cs/home/ss504/Documents/Personal/stacshack25/buzzwords/.venv/lib64/python3.9/site-packages/transformers/utils/import_utils.py:1865, in _LazyModule._get_module(self, module_name)
#    1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
# -> 1865     raise RuntimeError(
#    1866         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1867         f" traceback):\n{e}"
#    1868     ) from e
#
# RuntimeError: Failed to import transformers.models.llama.modeling_llama because of the following error (look up to see its traceback):
# partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
